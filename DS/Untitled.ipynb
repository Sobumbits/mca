# %%
import numpy as np

# %%
c=np.array([[1,2],[3,4]])

# %%
print(c)
# Out:
# [[1 2]
#  [3 4]]

# %%
print(c.shape)
# Out:
# (2, 2)

# %%
a=np.random.random((4,4))

# %%
a=np.random.randint((4,4))

# %%
print (a)
# Out:
# [0 3]

# %%
b=np.random.randint(0,10,(4,4))

# %%
print (b)
# Out:
# [[4 1 5 8]
#  [8 6 1 6]
#  [9 4 0 0]
#  [1 9 2 3]]

# %%
print (b.transpose())
# Out:
# [[4 8 9 1]
#  [1 6 4 9]
#  [5 1 0 2]
#  [8 6 0 3]]

# %%
d=b.transpose()

# %%
result=np.dot(c,d)

# %%
print (result)
# Out:
# [[ 5 11]
#  [11 25]]

# %%
result1=np.dot(b,d)

# %%
print(result1)
# Out:
# [[106  91  40  47]
#  [ 91 137  96  82]
#  [ 40  96  97  45]
#  [ 47  82  45  95]]
